# %%
import pandas as pd

# 파일을 읽어옵니다.
df = pd.read_excel('C:/Users/winbb/Desktop/20162020.xlsx')

# '2016' 열을 추출합니다.
column_2016 = df['2016']

# '2017' 열을 추출합니다.
column_2017 = df['2017']

# '2018' 열을 추출합니다.
column_2018 = df['2018']

# '2019' 열을 추출합니다.
column_2019 = df['2019']

# '2020' 열을 추출합니다.
column_2020 = df['2020']

# '2016', '2017', '2018', '2019', '2020' 열을 순서대로 합칩니다.
df = pd.concat([column_2016, column_2017, column_2018, column_2019, column_2020], axis=1)

# 수정된 데이터프레임을 저장합니다.
df.to_excel('C:/Users/winbb/Desktop/qwert.xlsx', index=False)
# Out:
# c:\Users\winbb\AppData\Local\Programs\Python\Python39\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 상관분석
import pandas as pd
import numpy as np

# 파일 경로 설정
file_path = 'C:/Users/winbb/Desktop/final.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)

# 숫자 데이터만 포함된 열 선택 (연도 제외)
numeric_columns = df.select_dtypes(include=[np.number]).drop('연도', axis=1)

# 상관관계 분석
correlation_matrix = numeric_columns.corr()

# 상관계수 출력
print(correlation_matrix)

# XLSX 파일로 저장
output_file_path = 'C:/Users/winbb/Desktop/correlation_matrix2.xlsx'
correlation_matrix.to_excel(output_file_path, sheet_name='Correlation', index=False)
print("상관계수를 correlation_matrix.xlsx 파일로 저장했습니다.")
# Out:
#            인구 (명)   구성비 (%)
# 인구 (명)   1.000000  0.929316
# 구성비 (%)  0.929316  1.000000
# 상관계수를 correlation_matrix.xlsx 파일로 저장했습니다.

# %%
#단순선형회귀 분포도 산점도

import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 파일 경로 설정
file_path = 'C:/Users/winbb/Desktop/final.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)

# 단순선형회귀분석을 위한 데이터 선택
X = df['인구 (명)']  # 독립 변수 선택
Y = df['구성비 (%)']  # 종속 변수 선택

# 상수 항 추가
X = sm.add_constant(X)

# 단순선형회귀모델 학습
model = sm.OLS(Y, X)
results = model.fit()

# 회귀분석 결과 출력
print(results.summary())

# 회귀선과 산점도 그래프 그리기
plt.scatter(X['인구 (명)'], Y, alpha=0.5)  # 산점도
plt.plot(X['인구 (명)'], results.predict(), color='red')  # 회귀선
plt.xlabel('인구 (명)')
plt.ylabel('구성비 (%)')
plt.title('단순선형회귀 분포도')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                구성비 (%)   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1697.
# Date:                Tue, 20 Jun 2023   Prob (F-statistic):          5.91e-118
# Time:                        06:24:23   Log-Likelihood:                -944.53
# No. Observations:                 270   AIC:                             1893.
# Df Residuals:                     268   BIC:                             1900.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5156      0.541      2.800      0.005       0.450       2.581
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 파일 경로 설정
file_path = 'C:/Users/winbb/Desktop/final.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)

# 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 숫자 데이터만 포함된 열 선택 (연도 제외)
numeric_columns = df.select_dtypes(include=[np.number]).drop('연도', axis=1)

# 상관관계 분석
correlation_matrix = numeric_columns.corr()

# 상관계수 히트맵
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='RdYlBu')
plt.title('인구, 구성비 상관관계')
plt.show()
